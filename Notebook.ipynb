# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from bs4 import BeautifulSoup
import requests
from html.parser import HTMLParser

# %%
url = requests.get("https://en.wikipedia.org/wiki/Crab").text

# %%
table = soup.find("table",{"class":"clade"})

# %%
table
# Out:
# <table class="clade" style="font-size:85%; line-height:85%">
# <tbody><tr>
# <td class="clade-label first"><b><a href="/wiki/Decapoda" title="Decapoda">Decapoda</a></b>
# </td>
# <td class="clade-leaf" rowspan="2">
# <link href="mw-data:TemplateStyles:r1129740115" rel="mw-deduplicated-inline-style"/>
# <table class="clade">
# <tbody><tr>
# <td class="clade-label first">
# </td>
# <td class="clade-leaf" rowspan="2">
# <p><a href="/wiki/Dendrobranchiata" title="Dendrobranchiata">Dendrobranchiata</a> (prawns) <a class="image" href="/wiki/File:Litopenaeus_setiferus.png"><img alt="Litopenaeus setiferus.png" data-file-height="150" data-file-width="248" decoding="async" height="30" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/86/Litopenaeus_setiferus.png/50px-Litopenaeus_setiferus.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/86/Litopenaeus_setiferus.png/75px-Litopenaeus_setiferus.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/86/Litopenaeus_setiferus.png/100px-Litopenaeus_setiferus.png 2x" width="50"/></a>
# </p>
# </td></tr>
# <tr>
# <td class="clade-slabel">
# </td></tr>
# <tr>
# <td class="clade-label"><a href="/wiki/Pleocyemata" title="Pleocyemata">Pleocyemata</a>
# </td>
# <td class="clade-leaf" rowspan="2">
# <link href="mw-data:TemplateStyles:r1129740115" rel="mw-deduplicated-inline-style"/>
# <table class="clade">
# <tbody><tr>
# <td class="clade-label first">
# </td>
# <td class="clade-leaf" rowspan="2">
# <link href="mw-data:TemplateStyles:r1129740115" rel="mw-deduplicated-inline-style"/>
# <table class="clade">
# <tbody><tr>
# <td class="clade-label first">
# </td>
# <td class="clade-leaf" rowspan="2">
# <p><a href="/wiki/Stenopodidea" title="Stenopodidea">Stenopodidea</a> (boxer shrimp) <a class="image" href="/wiki/File:Spongicola_venustus.png"><img alt="Spongicola venustus.png" data-file-height="1100" data-file-width="1500" decoding="async" height="37" src="//upload.wikimedia.org/wikipedia/commons/thumb/6/64/Spongicola_venustus.png/50px-Spongicola_venustus.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/6/64/Spongicola_venustus.png/75px-Spongicola_venustus.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/6/64/Spongicola_venustus.png/100px-Spongicola_venustus.png 2x" width="50"/></a>
# </p>
# </td></tr>
# <tr>
# <td class="clade-slabel">
# </td></tr>
# <tr>
# <td class="clade-label">
# </td>
# <td class="clade-leaf" rowspan="2">
# <link href="mw-data:TemplateStyles:r1129740115" rel="mw-deduplicated-inline-style"/>
# <table class="clade">
# <tbody><tr>
# <td class="clade-label first">
# </td>
# <td class="clade-leaf" rowspan="2">
# <p><a href="/wiki/Procarididea" title="Procarididea">Procarididea</a>
# </p>
# </td></tr>
# <tr>
# <td class="clade-slabel">
# </td></tr>
# <tr>
# <td class="clade-label">
# </td>
# <td class="clade-leaf" rowspan="2">
# <p><a href="/wiki/Caridea" title="Caridea">Caridea</a> (true shrimp) <a class="image" href="/wiki/File:Macrobrachium_sp.jpg"><img alt="Macrobrachium sp.jpg" data-file-height="2671" data-file-width="4691" decoding="async" height="28" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/74/Macrobrachium_sp.jpg/50px-Macrobrachium_sp.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/74/Macrobrachium_sp.jpg/75px-Macrobrachium_sp.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/74/Macrobrachium_sp.jpg/100px-Macrobrachium_sp.jpg 2x" width="50"/></a>
# </p>
# </td></tr>
# <tr>
# <td class="clade-slabel last">
# </td></tr></tbody></table>
# </td></tr>
# <tr>
# <td class="clade-slabel last">
# </td></tr></tbody></table>
# </td></tr>
# <tr>
# <td class="clade-slabel">
# </td></tr>
# <tr>
# <td class="clade-label"><a href="/wiki/Reptantia" title="Reptantia">Reptantia</a>
# </td>
# <td class="clade-leaf" rowspan="2">
# <link href="mw-data:TemplateStyles:r1129740115" rel="mw-deduplicated-inline-style"/>
# <table class="clade">
# <tbody><tr>
# <td class="clade-label first">
# </td>
# <td class="clade-leaf" rowspan="2">
# <link href="mw-data:TemplateStyles:r1129740115" rel="mw-deduplicated-inline-style"/>
# <table class="clade">
# <tbody><tr>
# <td class="clade-label first">
# </td>
# <td class="clade-leaf" rowspan="2">
# <p><a href="/wiki/Achelata" title="Achelata">Achelata</a> (spiny lobsters, slipper lobsters) <a class="image" href="/wiki/File:Panulirus_argus.png"><img alt="Panulirus argus.png" data-file-height="150" data-file-width="248" decoding="async" height="30" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b5/Panulirus_argus.png/50px-Panulirus_argus.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b5/Panulirus_argus.png/75px-Panulirus_argus.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b5/Panulirus_argus.png/100px-Panulirus_argus.png 2x" width="50"/></a>
# </p>
# </td></tr>
# <tr>
# <td class="clade-slabel">
# </td></tr>
# <tr>
# <td class="clade-label">
# </td>
# <td class="clade-leaf" rowspan="2">
# <link href="mw-data:TemplateStyles:r1129740115" rel="mw-deduplicated-inline-style"/>
# <table class="clade">
# <tbody><tr>
# <td class="clade-label first">
# </td>
# <td class="clade-leaf" rowspan="2">
# <p><a href="/wiki/Polychelida" title="Polychelida">Polychelida</a> (benthic crustaceans)
# </p>
# </td></tr>
# <tr>
# <td class="clade-slabel">
# </td></tr>
# <tr>
# <td class="clade-label">
# </td>
# <td class="clade-leaf" rowspan="2">
# <p><a href="/wiki/Astacidea" title="Astacidea">Astacidea</a> (lobsters, crayfish) <a class="image" href="/wiki/File:Lobster_NSRW_rotated2.jpg"><img alt="Lobster NSRW rotated2.jpg" data-file-height="1802" data-file-width="2679" decoding="async" height="34" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/5d/Lobster_NSRW_rotated2.jpg/50px-Lobster_NSRW_rotated2.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/5d/Lobster_NSRW_rotated2.jpg/75px-Lobster_NSRW_rotated2.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/5d/Lobster_NSRW_rotated2.jpg/100px-Lobster_NSRW_rotated2.jpg 2x" width="50"/></a>
# </p>
# </td></tr>
# <tr>
# <td class="clade-slabel last">
# </td></tr></tbody></table>
# </td></tr>
# <tr>
# <td class="clade-slabel last">
# </td></tr></tbody></table>
# </td></tr>
# <tr>
# <td class="clade-slabel">
# </td></tr>
# <tr>
# <td class="clade-label">
# </td>
# <td class="clade-leaf" rowspan="2">
# <link href="mw-data:TemplateStyles:r1129740115" rel="mw-deduplicated-inline-style"/>
# <table class="clade">
# <tbody><tr>
# <td class="clade-label first">
# </td>
# <td class="clade-leaf" rowspan="2">
# <p><a href="/wiki/Axiidea" title="Axiidea">Axiidea</a> (mud shrimp, ghost shrimp, or burrowing shrimp)
# </p>
# </td></tr>
# <tr>
# <td class="clade-slabel">
# </td></tr>
# <tr>
# <td class="clade-label">
# </td>
# <td class="clade-leaf" rowspan="2">
# <link href="mw-data:TemplateStyles:r1129740115" rel="mw-deduplicated-inline-style"/>
# <table class="clade">
# <tbody><tr>
# <td class="clade-label first">
# </td>
# <td class="clade-leaf" rowspan="2">
# <p><a href="/wiki/Gebiidea" title="Gebiidea">Gebiidea</a> (mud lobsters and mud shrimp)
# </p>
# </td></tr>
# <tr>
# <td class="clade-slabel">
# </td></tr>
# <tr>
# <td class="clade-label"><a class="new" href="/w/index.php?title=Meiura&amp;action=edit&amp;redlink=1" title="Meiura (page does not exist)">Meiura</a>
# </td>
# <td class="clade-leaf" rowspan="2">
# <link href="mw-data:TemplateStyles:r1129740115" rel="mw-deduplicated-inline-style"/>
# <table class="clade">
# <tbody><tr>
# <td class="clade-label first">
# </td>
# <td class="clade-leaf" rowspan="2">
# <p><a href="/wiki/Anomura" title="Anomura">Anomura</a> (hermit crabs and others) <a class="image" href="/wiki/File:Coenobita_variabilis.jpg"><img alt="Coenobita variabilis.jpg" data-file-height="597" data-file-width="800" decoding="async" height="37" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/4a/Coenobita_variabilis.jpg/50px-Coenobita_variabilis.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/4a/Coenobita_variabilis.jpg/75px-Coenobita_variabilis.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/4a/Coenobita_variabilis.jpg/100px-Coenobita_variabilis.jpg 2x" width="50"/></a>
# </p>
# </td></tr>
# <tr>
# <td class="clade-slabel">
# </td></tr>
# <tr>
# <td class="clade-label">
# </td>
# <td class="clade-leaf" rowspan="2">
# <p><b>Brachyura</b> (crabs) <a class="image" href="/wiki/File:Charybdis_japonica.jpg"><img alt="Charybdis japonica.jpg" data-file-height="1200" data-file-width="1600" decoding="async" height="38" src="//upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Charybdis_japonica.jpg/50px-Charybdis_japonica.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Charybdis_japonica.jpg/75px-Charybdis_japonica.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Charybdis_japonica.jpg/100px-Charybdis_japonica.jpg 2x" width="50"/></a>
# </p>
# </td></tr>
# <tr>
# <td class="clade-slabel last">
# </td></tr></tbody></table>
# </td></tr>
# <tr>
# <td class="clade-slabel last">
# </td></tr></tbody></table>
# </td></tr>
# <tr>
# <td class="clade-slabel last">
# </td></tr></tbody></table>
# </td></tr>
# <tr>
# <td class="clade-slabel last">
# </td></tr></tbody></table>
# </td></tr>
# <tr>
# <td class="clade-slabel last">(crawling/walking decapods)
# </td></tr></tbody></table>
# </td></tr>
# <tr>
# <td class="clade-slabel last">
# </td></tr></tbody></table>
# </td></tr>
# <tr>
# <td class="clade-slabel last">
# </td></tr></tbody></table>
